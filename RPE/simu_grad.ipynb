# %% [markdown]
# # Simulation
# We simulate the gradient flow in this code

# %%
# Let us load the data model
from dataset import NGramDataset
from IPython.display import Math
from typing import Union

# Initialize the dataset
S, L, n_language, alpha, n_sample = 3, 100, 3, 0.3, 1
dataset = NGramDataset(S, L, n_language, alpha, n_sample)
n = n_language - 1

# Get the transition matrix pi
pi = dataset.pi

# Associate each row of pi with a (n-1) vector with elements in {0, 1, ..., S-1} by decoding the index into a base-S number
def ind2code(ind, S, n):
    """Decode the index into a base-S number"""
    assert ind < S**n
    code = [0 for _ in range(n)]
    for j in range(n):
        code[n - j - 1] = ind % S
        ind //= S
    return code
def code2ind(code, S):
    """Encode the base-S number into an index"""
    n = len(code)
    return sum([code[j] * S**(n-j-1) for j in range(n)])
def next_state(parent, son, S, n):
    """Return the next state of the Markov chain given the current state i and the next symbol j
    
    Args:
    parent: Union[int, list], the parent context
    son: int, the next symbol
    S: int, the number of symbols in the alphabet
    n: int, the length of parent context

    Returns:
    state: Union[int, list], the next state of the Markov chain, the form is determined by the input parent
    """
    if isinstance(parent, int):
        return parent // S + son * S**(n-1)
    else:
        return [son] + parent[0:-1]

# Test the functions
for i in range(S**n):
    print(f'pi{ind2code(i, S, n)}: {pi[i]}')

i, j = 5, 2
print(f'The next state (i, j)={(i, j)}:\t', next_state(i, j, S, n))
print(f'The next state (i, j)={(ind2code(i, S, n), j)}:\t', next_state(ind2code(i, S, n), j, S, n))
# Out:
# pi[0, 0]: tensor([0.0017, 0.0571, 0.9411])
# pi[0, 1]: tensor([0.1538, 0.2974, 0.5488])
# pi[0, 2]: tensor([0.0043, 0.0388, 0.9569])
# pi[1, 0]: tensor([2.7469e-04, 8.4797e-01, 1.5175e-01])
# pi[1, 1]: tensor([0.8935, 0.0184, 0.0881])
# pi[1, 2]: tensor([0.0015, 0.6416, 0.3569])
# pi[2, 0]: tensor([0.0359, 0.1596, 0.8045])
# pi[2, 1]: tensor([0.0111, 0.8213, 0.1677])
# pi[2, 2]: tensor([0.2471, 0.0035, 0.7495])
# The next state (i, j)=(5, 2):	 7
# The next state (i, j)=([1, 2], 2):	 [2, 1]

# %%
# Let's take a random distribution over the S**n states
import torch
import numpy as np

def get_stationary(pi, S, n, max_iter=100, seed_index=0, output=False):
    """Get the stationary distribution of the Markov chain
    
    Args:
    pi: torch.tensor, the transition matrix
    S: int, the number of symbols in the alphabet
    n: int, the length of the context
    max_iter: int, the maximum number of iterations
    seed_index: int, the index of the seed distribution

    Returns:
    x: torch.tensor, the stationary distribution
    """
    # initialize x
    x = torch.rand(S**n, 1)
    x /= x.sum()

    # get the joint distribution of the parent and the son
    for i in range(100):
        y = x * pi
        # transpose and reshape
        y = y.transpose(0, 1).reshape(-1).reshape(-1, S).sum(axis=-1, keepdims=True)

        # take the TV distance
        d = torch.abs(x - y).sum()
        # print(f'Iteration {i+1}, TV distance: {d}')

        # update x
        x = y
    if output:
        print(f'Final TV distance after {i+1} iterations: {d}')
    return x, d

pi = NGramDataset(S, L, n_language, alpha, n_sample).pi
# Let's test the function
mu, _ = get_stationary(pi, S, n)

# Let's histogram the stationary distribution
import matplotlib.pyplot as plt

def plot_hist(y, S, n, title='Stationary distribution'):
    """Plot the stationary distribution"""
    plt.bar(range(S**n), y.reshape(-1))
    plt.xlabel('State')
    plt.title(title)
    # add the state's code to the x-axis
    plt.xticks(range(S**n), [f'{i}:{ind2code(i, S, n)}' for i in range(S**n)], rotation=-90)
    plt.show()
    
plot_hist(mu, S, n)

# %%
# get the stationary distribution for window size 1
def get_stationary_single_symbol(mu, n):
    S = int(np.exp(np.log(len(mu.squeeze())) / n))
    return mu.reshape(S, -1).sum(axis=-1, keepdims=False)

# calculate the chi-square mutual information
def chi_square_mutual_info(parent, pi, mu):
    S = pi.shape[1]
    # n = log(S, pi.shape[0])
    n = int(np.log(pi.shape[0]) / np.log(S))

    # get the stationary distribution for one symbol
    mu_single = get_stationary_single_symbol(mu, n)
    
    if parent != -1:
        if isinstance(parent, list):
            parent = code2ind(parent, S)
        p = pi[parent]

        # the chi-square mutual information between mu_single and p
        return (p ** 2 / mu_single).sum() - 1

    # take the average over all the parents
    return mu.reshape(1, -1) @ (pi ** 2 / mu_single.reshape(1, -1)).sum(axis=-1, keepdims=True)


# Let's test the function
parent = [0, 1]
print(f'chi_square for parent {parent}:{chi_square_mutual_info(parent, pi, mu)}')
print(f'chi_square for parent -1:{chi_square_mutual_info(-1, pi, mu)}')
# Out:
# chi_square for parent [0, 1]:0.7668095827102661
# chi_square for parent -1:tensor([[2.0857]])

# %% [markdown]
# Let us plot the stationary distribution for (n-1)-parents

# %%
from tqdm import tqdm, trange
# Initialize the dataset
S, L, n_language, alpha, n_sample = 3, 100, 3, 0.3, 1
n = n_language - 1
num_test = 100

pbar = tqdm(range(num_test),ncols=100,mininterval=1)
mu = torch.zeros(num_test, S**n)
mutual_info = torch.zeros(num_test, 2**n)
for j in pbar:
    dataset = NGramDataset(S, L, n_language, alpha, n_sample)
    pi = dataset.pi
    if j % 20 == 0:
        pbar.set_description(f'Iteration {j+1}/{num_test}')
        x, _ = get_stationary(pi, S, n, output=False)
    else: 
        x, _ = get_stationary(pi, S, n)

    mu[j] = x.reshape(-1)

    # compute the mutual information
    for ind in range(2**n):
        support = ind2code(ind, 2, n)
        

mean = mu.mean(axis=0)
std = mu.std(axis=0)

# Let's plot the mean and standard deviation of the stationary distribution
plot_hist(mean.numpy(), S, n, title=f'Mean of the stationary distribution: S={S},n={n},L={L},alpha={alpha},num_test={num_test}')
plot_hist(std.numpy(), S, n, title=f'Standard deviation of the stationary distribution: S={S},n={n},L={L},alpha={alpha},num_test={num_test}')
# Out:
# Iteration 81/100: 100%|███████████████████████████████████████████| 100/100 [00:01<00:00, 81.40it/s]

# %%
# Initialize the dataset
S, L, n_language, alpha, n_sample = 3, 100, 3, 1.0, 1
n = n_language - 1
num_test = 100

mu = torch.zeros(num_test, S**n)
for j in range(num_test):
    dataset = NGramDataset(S, L, n_language, alpha, n_sample)
    pi = dataset.pi
    if j % 20 == 0:
        print(f'Test {j+1}')
        x, _ = get_stationary(pi, S, n, output=True)
    else: 
        x, _ = get_stationary(pi, S, n)

    mu[j] = x.reshape(-1)

mean = mu.mean(axis=0)
std = mu.std(axis=0)

# Let's plot the mean and standard deviation of the stationary distribution
plot_hist(mean.numpy(), S, n, title=f'Mean of the stationary distribution: S={S},n={n},L={L},alpha={alpha},num_test={num_test}')
plot_hist(std.numpy(), S, n, title=f'Standard deviation of the stationary distribution: S={S},n={n},L={L},alpha={alpha},num_test={num_test}')
# Out:
# Generating datasets...
# Test 1
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 5.029141902923584e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.1175870895385742e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 9.406358003616333e-08
# Generating datasets...
# Test 21
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.725290298461914e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.9802322387695312e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 7.636845111846924e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 7.82310962677002e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 41
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.725290298461914e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.725290298461914e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.725290298461914e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 4.470348358154297e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 61
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.728775143623352e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.2351741790771484e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 81
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 9.797513484954834e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 9.313225746154785e-09
# Generating datasets...
# Final TV distance after 100 iterations: 1.5273690223693848e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0

# %%
# Initialize the dataset
S, L, n_language, alpha, n_sample = 3, 100, 4, 1.0, 1
n = n_language - 1
num_test = 500

mu = torch.zeros(num_test, S**n)
for j in range(num_test):
    dataset = NGramDataset(S, L, n_language, alpha, n_sample)
    pi = dataset.pi
    if j % 20 == 0:
        print(f'Test {j+1}')
        x, _ = get_stationary(pi, S, n, output=True)
    else: 
        x, _ = get_stationary(pi, S, n)

    mu[j] = x.reshape(-1)

mean = mu.mean(axis=0)
std = mu.std(axis=0)

# Let's plot the mean and standard deviation of the stationary distribution
plot_hist(mean.numpy(), S, n, title=f'Mean of the stationary distribution: S={S},n={n},L={L},alpha={alpha},num_test={num_test}')
plot_hist(std.numpy(), S, n, title=f'Standard deviation of the stationary distribution: S={S},n={n},L={L},alpha={alpha},num_test={num_test}')
# Out:
# Generating datasets...
# Test 1
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.537854015827179e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.60770320892334e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 8.055940270423889e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 21
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.60770320892334e-08
# Generating datasets...
# Final TV distance after 100 iterations: 1.2293457984924316e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.30385160446167e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 41
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 7.450580596923828e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 7.450580596923828e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.2351741790771484e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 61
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.421438694000244e-08
# Generating datasets...
# Final TV distance after 100 iterations: 1.6763806343078613e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.5390257835388184e-08
# Generating datasets...
# Final TV distance after 100 iterations: 2.2817403078079224e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 81
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 9.071081876754761e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 7.450580596923828e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.725290298461914e-09
# Generating datasets...
# Final TV distance after 100 iterations: 8.791685104370117e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 8.940696716308594e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 6.51925802230835e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 4.470348358154297e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 101
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.30385160446167e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 4.563480615615845e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 4.563480615615845e-08
# Generating datasets...
# Final TV distance after 100 iterations: 3.725290298461914e-09
# Generating datasets...
# Test 121
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 7.450580596923828e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.7939677238464355e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.725290298461914e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.2351741790771484e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 9.778887033462524e-09
# Generating datasets...
# Final TV distance after 100 iterations: 7.450580596923828e-08
# Generating datasets...
# Test 141
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 9.313225746154785e-10
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0001777326688170433
# Generating datasets...
# Final TV distance after 100 iterations: 6.51925802230835e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 161
# Final TV distance after 100 iterations: 1.955777406692505e-08
# Generating datasets...
# Final TV distance after 100 iterations: 4.936009645462036e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.9802322387695312e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.0489096641540527e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 181
# Final TV distance after 100 iterations: 3.5390257835388184e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 7.450580596923828e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.387670636177063e-07
# Generating datasets...
# Final TV distance after 100 iterations: 2.60770320892334e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.91155481338501e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 201
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.909211277961731e-08
# Generating datasets...
# Final TV distance after 100 iterations: 1.862645149230957e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 4.6566128730773926e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 8.381903171539307e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.7939677238464355e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.862645149230957e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 221
# Final TV distance after 100 iterations: 5.587935447692871e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.862645149230957e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.1175870895385742e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.8870999813079834e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 241
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.4458935260772705e-08
# Generating datasets...
# Final TV distance after 100 iterations: 4.423782229423523e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.166496753692627e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 261
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 4.237517714500427e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.0477378964424133e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.5133991837501526e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.166496753692627e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 281
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.210719347000122e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 5.168840289115906e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.2351741790771484e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.5832483768463135e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 301
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.4901161193847656e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 321
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.4901161193847656e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.2351741790771484e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.4458935260772705e-08
# Generating datasets...
# Final TV distance after 100 iterations: 1.30385160446167e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.60770320892334e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.1175870895385742e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 341
# Final TV distance after 100 iterations: 5.122274160385132e-08
# Generating datasets...
# Final TV distance after 100 iterations: 2.0489096641540527e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 5.681067705154419e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 361
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.0244548320770264e-08
# Generating datasets...
# Final TV distance after 100 iterations: 1.1175870895385742e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 5.029141902923584e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 8.381903171539307e-09
# Generating datasets...
# Final TV distance after 100 iterations: 7.450580596923828e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 381
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0004977872595191002
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 7.450580596923828e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 4.470348358154297e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.6763806343078613e-08
# Generating datasets...
# Test 401
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.026798367500305e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 421
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.9802322387695312e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.91155481338501e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.537854015827179e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 9.313225746154785e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.862645149230957e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 5.727633833885193e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 441
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.862645149230957e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.955777406692505e-08
# Generating datasets...
# Final TV distance after 100 iterations: 2.3283064365386963e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 9.313225746154785e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 4.6566128730773926e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Test 461
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.5832483768463135e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.4901161193847656e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.816079020500183e-07
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.7695128917694092e-08
# Generating datasets...
# Test 481
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.7229467630386353e-06
# Generating datasets...
# Final TV distance after 100 iterations: 8.381903171539307e-09
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.7008354663848877e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 3.026798367500305e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 1.1175870895385742e-08
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 0.0
# Generating datasets...
# Final TV distance after 100 iterations: 2.2351741790771484e-08
